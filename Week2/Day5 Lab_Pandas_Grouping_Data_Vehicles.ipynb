# %% [markdown]
# # Pandas: grouping

# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("Data/vehicles.csv")

# %%
cars.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# How many Car models?

# %%
### your code is here
n = cars.Model.nunique()
print("No.of.unique values in Model column :",
      n)
# Out:
# No.of.unique values in Model column : 3608

# %% [markdown]
# group by the data by the Make  using count function

# %%
### your code us here

cars_col_num =  cars.groupby('Make').count()
cars_col_num
# Out:
#                              Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General                       4     4                    4          4
# ASC Incorporated                 1     1                    1          1
# Acura                          302   302                  302        302
# Alfa Romeo                      41    41                   41         41
# American Motors Corporation     22    22                   22         22
# ...                            ...   ...                  ...        ...
# Volkswagen                    1047  1047                 1047       1047
# Volvo                          717   717                  717        717
# Wallace Environmental           32    32                   32         32
# Yugo                             8     8                    8          8
# smart                           20    20                   20         20
#
#                              Transmission  Drivetrain  Vehicle Class  \
# Make
# ...

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$
#
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# What brand has the most cars?

# %%
### your code us here
cars["Make"].value_counts()
# Out:
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
#                                       ...
# Excalibur Autos                          1
# S and S Coach Company  E.p. Dutton       1
# Environmental Rsch and Devp Corp         1
# E. P. Dutton, Inc.                       1
# Lambda Control Systems                   1
# Name: Make, Length: 127, dtype: int64

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand

# %%
### your code us here
cars.groupby(["Make", "CO2 Emission Grams/Mile"])["CO2 Emission Grams/Mile"].mean()
# Out:
# Make              CO2 Emission Grams/Mile
# AM General        522.764706                 522.764706
#                   555.437500                 555.437500
#                   683.615385                 683.615385
# ASC Incorporated  555.437500                 555.437500
# Acura             228.000000                 228.000000
#                                                 ...
# smart             246.000000                 246.000000
#                   246.861111                 246.861111
#                   251.000000                 251.000000
#                   255.000000                 255.000000
#                   258.000000                 258.000000
# Name: CO2 Emission Grams/Mile, Length: 3582, dtype: float64

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand ... sorted

# %%
### your code us here
cars.sort_values("CO2 Emission Grams/Mile", ascending=False)
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# ...            ...       ...   ...                  ...        ...
# 7917     Chevrolet      Volt  2017                  1.5        4.0
# 7916     Chevrolet      Volt  2016                  1.5        4.0
# 3070           BMW    i3 REX  2015                  0.6        2.0
# 3069           BMW    i3 REX  2014                  0.6        2.0
# 3071           BMW    i3 REX  2016                  0.6        2.0
#
#                            Transmission         Drivetrain    Vehicle Class  \
# 20897                      Manual 5-spd   Rear-Wheel Drive      Two Seaters
# ...

# %% [markdown]
# (Optional) Use `pd.cut` or `pd.qcut` to create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
## your code here
cars.groupby("Year").mean()
# Out:
#       Engine Displacement  Cylinders  Fuel Barrels/Year   City MPG  \
# Year
# 1984             3.927752   6.102326          21.185192  15.485271
# 1985             3.170462   5.388362          18.090052  17.872233
# 1986             3.184764   5.430976          18.201528  17.675926
# 1987             3.138815   5.384808          18.373926  17.414858
# 1988             3.201698   5.469169          18.311235  17.321716
# 1989             3.200710   5.476486          18.495810  17.161491
# 1990             3.218633   5.498127          18.544667  17.035581
# 1991             3.271747   5.603387          18.726021  16.837790
# 1992             3.279313   5.628726          18.640426  16.800361
# 1993             3.243083   5.595172          18.306114  17.029712
# 1994             3.342296   5.712513          18.350004  16.916236
# 1995             3.462069   5.868534          18.627154  16.599138
# 1996             3.236375   5.624511          17.764682  17.301173
# ...

# %% [markdown]
# ### Did cars consume more gas in the eighties?

# %% [markdown]
# show the average City_Km/Liter by year_range

# %%
### your code is here

# %% [markdown]
# Which brands are more environment friendly?

# %%
### your code is here
cars.groupby(["Make", "Model", "Year"])[["Fuel Barrels/Year", "CO2 Emission Grams/Mile"]].mean()
# Out:
#                                            Fuel Barrels/Year  \
# Make             Model               Year
# AM General       DJ Po Vehicle 2WD   1984          19.388824
#                  FJ8c Post Office    1984          25.354615
#                  Post Office DJ5 2WD 1985          20.600625
#                  Post Office DJ8 2WD 1985          25.354615
# ASC Incorporated GNX                 1987          20.600625
# ...                                                      ...
# smart            fortwo coupe        2012           9.155833
#                                      2013           9.155833
#                                      2014           9.155833
#                                      2015           9.155833
#                                      2016           9.286631
#
#                                            CO2 Emission Grams/Mile
# Make             Model               Year
# AM General       DJ Po Vehicle 2WD   1984               522.764706
# ...

# %% [markdown]
# Does the drivetrain affect fuel consumption?

# %%
## Your Code here

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
## Your Code here
cars.groupby(["Make", "Transmission"])[["Fuel Barrels/Year"]].mean()
# Out:
#                                   Fuel Barrels/Year
# Make             Transmission
# AM General       Automatic 3-spd          22.674670
# ASC Incorporated Automatic 4-spd          20.600625
# Acura            Auto(AM-S7)              11.365862
#                  Auto(AM-S8)              11.636478
#                  Auto(AM-S9)              15.695714
# ...                                             ...
# smart            Auto(AM5)                 9.155833
#                  Auto(AM6)                 9.286631
#                  Automatic (AM5)           9.155833
#                  Automatic (S5)            9.155833
#                  Manual 5-spd              9.555920
#
# [580 rows x 1 columns]

# %% [markdown]
# Use `groupby` and `agg` with different aggregation measures for different columns:

# %% [markdown]
# aggregate with average City_Km/Liter and the count of the Trans

# %%
## your code is here

# %% [markdown]
# aggregate with average City_Km/Liter and the minimum of the Trans

# %%
### your code is here
